# %%
import pandas as pd
import chromadb
from config.settings import settings

# %%
client = chromadb.HttpClient(
    host=settings.CHROMA_HOST,
    port=settings.CHROMA_PORT,
)

# %%
client.heartbeat()
# Out:
# 1771683088164822803

# %%
collection = client.get_collection(name=settings.COLLECTION_NAME)

# %%
collection.count()
# Out:
# 42

# %%
data = collection.get(
    limit=100,
    offset=0,
    # include=["embeddings"]
)

# %%
df = pd.DataFrame({
    "id": data["ids"],
    "document": data["documents"],
    "metadata": data["metadatas"],
    "embedding": data["embeddings"],  # список float внутри каждой строки

})

# %%
df
# Out:
#                                            id  \
# 0    e872549b899aa7cdbd91db17c38683b3_chunk_0
# 1    e872549b899aa7cdbd91db17c38683b3_chunk_1
# 2    e872549b899aa7cdbd91db17c38683b3_chunk_2
# 3    e872549b899aa7cdbd91db17c38683b3_chunk_3
# 4    e872549b899aa7cdbd91db17c38683b3_chunk_4
# 5    e872549b899aa7cdbd91db17c38683b3_chunk_5
# 6    bf2f4bebe78c95e5abe8bcb821eacd54_chunk_0
# 7    bf2f4bebe78c95e5abe8bcb821eacd54_chunk_1
# 8    bf2f4bebe78c95e5abe8bcb821eacd54_chunk_2
# 9    bf2f4bebe78c95e5abe8bcb821eacd54_chunk_3
# 10   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_4
# 11   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_5
# 12   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_6
# 13   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_7
# 14   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_8
# 15   bf2f4bebe78c95e5abe8bcb821eacd54_chunk_9
# 16  bf2f4bebe78c95e5abe8bcb821eacd54_chunk_10
# 17   6a4a514dbbb815b128e05612ff29ab8e_chunk_0
# 18   6a4a514dbbb815b128e05612ff29ab8e_chunk_1
# 19   6a4a514dbbb815b128e05612ff29ab8e_chunk_2
# 20   6a4a514dbbb815b128e05612ff29ab8e_chunk_3
# 21   6a4a514dbbb815b128e05612ff29ab8e_chunk_4
# 22   6a4a514dbbb815b128e05612ff29ab8e_chunk_5
# 23   6a4a514dbbb815b128e05612ff29ab8e_chunk_6
# 24   6a4a514dbbb815b128e05612ff29ab8e_chunk_7
# 25   6a4a514dbbb815b128e05612ff29ab8e_chunk_8
# 26   6a4a514dbbb815b128e05612ff29ab8e_chunk_9
# 27  6a4a514dbbb815b128e05612ff29ab8e_chunk_10
# 28   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_0
# 29   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_1
# 30   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_2
# 31   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_3
# 32   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_4
# 33   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_5
# 34   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_6
# 35   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_7
# 36   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_8
# 37   8ae66c94ebb3d7daeb5698c5bda03af2_chunk_9
# 38  8ae66c94ebb3d7daeb5698c5bda03af2_chunk_10
# 39  8ae66c94ebb3d7daeb5698c5bda03af2_chunk_11
# 40  8ae66c94ebb3d7daeb5698c5bda03af2_chunk_12
# 41  8ae66c94ebb3d7daeb5698c5bda03af2_chunk_13
#
#                                              document  \
# 0   РЕГЛАМЕНТ\nпо начислению и выплате бонусов сот...
# 1   Виды бонусов\nВ компании применяются следующие...
# 2   Разовый бонус — выплачивается за особые заслуг...
# 3   Размер бонуса пропорционально уменьшается за п...
# 4   Сотрудник имеет право ознакомиться с расчетом ...
# 5   С суммы бонуса удерживаются налоги и обязатель...
# 6   # РЕГЛАМЕНТ\n## по подбору и найму персонала\n...
# 7   1.4. Целями настоящего Регламента являются: об...
# 8   2.3. **Генеральный директор** — утверждает отк...
# 9   3.2. **Поиск кандидатов (5-15 рабочих дней)**\...
# 10  3.4. **Собеседования (7-10 рабочих дней)**\n**...
# 11  **Второе собеседование с руководителем подразд...
# 12  HR-департамент связывается минимум с двумя пре...
# 13  3.7. **Оформление на работу (2-5 рабочих дней)...
# 14  ### 4. Критерии оценки кандидатов\n4.1. **Обяз...
# 15  ### 5. Сроки и контроль процесса\n5.1. Общий с...
# 16  ### 6. Заключительные положения\n6.1. Все учас...
# 17  # РЕГЛАМЕНТ\n## процесса бюджетирования\n### О...
# 18  Бюджетный период в компании составляет один ка...
# 19  Руководители департаментов формируют бюджетные...
# 20  Бюджетный комитет в составе генерального дирек...
# 21  Формирование операционных бюджетов (октябрь) н...
# 22  Консолидация и согласование бюджета (ноябрь) о...
# 23  ### Исполнение и контроль бюджета\nЕжемесячно ...
# 24  Существенными признаются отклонения, превышающ...
# 25  Перераспределение средств между статьями в рам...
# 26  Для каждого показателя рассчитывается абсолютн...
# 27  Настоящий Регламент вступает в силу с момента ...
# 28  # РЕГЛАМЕНТ\n## разработки и внедрения аналити...
# 29  Все дашборды разрабатываются на единой платфор...
# 30  Аналитический департамент выполняет роль метод...
# 31  Служба безопасности согласовывает уровни досту...
# 32  В течение трех рабочих дней проводится встреча...
# 33  ### Базовый набор метрик для основных типов да...
# 34  Дашборды казино должны включать метрики валово...
# 35  Финансовые дашборды содержат метрики общей выр...
# 36  ### Этапы разработки и сроки\nПрототипирование...
# 37  Приемочное тестирование заказчиком проводится ...
# 38  ### Чек-лист перед релизом дашборда\nКорректно...
# 39  Визуализация и UX проверяются на соответствие ...
# 40  Безопасность и доступы проверяются через корре...
# 41  После запуска дашборд переходит в режим эксплу...
#
#                                              metadata embedding
# 0   {'chunk_index': 0, 'source': '/Users/victorchu...      None
# 1   {'chunk_index': 1, 'filename': 'bonuses.txt', ...      None
# 2   {'source': '/Users/victorchudnovskiy/Documents...      None
# 3   {'chunk_index': 3, 'source': '/Users/victorchu...      None
# 4   {'chunk_index': 4, 'filename': 'bonuses.txt', ...      None
# 5   {'source': '/Users/victorchudnovskiy/Documents...      None
# 6   {'source': '/Users/victorchudnovskiy/Documents...      None
# 7   {'source': '/Users/victorchudnovskiy/Documents...      None
# 8   {'filename': 'hiring.txt', 'chunk_index': 2, '...      None
# 9   {'filename': 'hiring.txt', 'source': '/Users/v...      None
# 10  {'chunk_index': 4, 'filename': 'hiring.txt', '...      None
# 11  {'chunk_index': 5, 'source': '/Users/victorchu...      None
# 12  {'filename': 'hiring.txt', 'chunk_index': 6, '...      None
# 13  {'filename': 'hiring.txt', 'chunk_index': 7, '...      None
# 14  {'chunk_index': 8, 'source': '/Users/victorchu...      None
# 15  {'filename': 'hiring.txt', 'chunk_index': 9, '...      None
# 16  {'source': '/Users/victorchudnovskiy/Documents...      None
# 17  {'source': '/Users/victorchudnovskiy/Documents...      None
# 18  {'source': '/Users/victorchudnovskiy/Documents...      None
# 19  {'source': '/Users/victorchudnovskiy/Documents...      None
# 20  {'chunk_index': 3, 'filename': 'budget.txt', '...      None
# 21  {'source': '/Users/victorchudnovskiy/Documents...      None
# 22  {'chunk_index': 5, 'source': '/Users/victorchu...      None
# 23  {'chunk_index': 6, 'source': '/Users/victorchu...      None
# 24  {'filename': 'budget.txt', 'source': '/Users/v...      None
# 25  {'chunk_index': 8, 'filename': 'budget.txt', '...      None
# 26  {'filename': 'budget.txt', 'source': '/Users/v...      None
# 27  {'chunk_index': 10, 'source': '/Users/victorch...      None
# 28  {'source': '/Users/victorchudnovskiy/Documents...      None
# 29  {'chunk_index': 1, 'filename': 'bi.txt', 'sour...      None
# 30  {'source': '/Users/victorchudnovskiy/Documents...      None
# 31  {'filename': 'bi.txt', 'source': '/Users/victo...      None
# 32  {'chunk_index': 4, 'source': '/Users/victorchu...      None
# 33  {'source': '/Users/victorchudnovskiy/Documents...      None
# 34  {'source': '/Users/victorchudnovskiy/Documents...      None
# 35  {'filename': 'bi.txt', 'source': '/Users/victo...      None
# 36  {'filename': 'bi.txt', 'chunk_index': 8, 'sour...      None
# 37  {'chunk_index': 9, 'filename': 'bi.txt', 'sour...      None
# 38  {'filename': 'bi.txt', 'source': '/Users/victo...      None
# 39  {'source': '/Users/victorchudnovskiy/Documents...      None
# 40  {'source': '/Users/victorchudnovskiy/Documents...      None
# 41  {'source': '/Users/victorchudnovskiy/Documents...      None

# %%
import pandas as pd
import chromadb
from src.settings import settings

# %%
client = chromadb.HttpClient(
    host=settings.CHROMA_HOST,
    port=settings.CHROMA_PORT,
)

# %%
client.heartbeat()
# Out:
# 1770821551248678385

# %%
collection = client.get_collection(name=settings.COLLECTION_NAME)

# %%
collection.count()
# Out:
# 24

# %%
data = collection.get(
    limit=100,
    offset=0,
    # include=["embeddings"]
)

# %%
df = pd.DataFrame({
    "id": data["ids"],
    "document": data["documents"],
    "metadata": data["metadatas"],
    "embedding": data["embeddings"],  # список float внутри каждой строки

})

# %%
df
# Out:
#                                       id  \
# 0   aaa8eeda-b14c-4518-9528-41fc00d0226d
# 1   08557a26-797e-4ef2-a730-1c29253bb5b1
# 2   29c7ebf9-4600-4849-aa72-f4b21dd28d01
# 3   902c45b3-28f9-46c6-bf1c-85d057ccd1e7
# 4   a641e6ae-6eab-4c80-ab97-6425755344e6
# 5   c95dc545-780e-46fa-95ac-cc59f80e217b
# 6   e3dc4a29-315c-4583-a252-d6a520d2c28c
# 7   bd0db5ae-fe12-4e52-bb45-70a2a1cbb9fc
# 8   548e061a-d9ee-4b3a-b8b3-259b78cd4a6b
# 9   149d50db-5c0a-451d-a8bc-e67fe24ba0bd
# 10  c678f2ba-55e8-4b44-a812-54aebd12739e
# 11  a4ed06fc-88c0-4375-8f7e-1bbac35b136a
# 12  3cf6634f-93e0-4b74-bfff-8ba56a69cf6b
# 13  c225f4ce-c13a-4d80-b055-43972d67d0c7
# 14  b5548e9e-eb6f-4805-864b-fffbf1192389
# 15  b65c7a2b-fed7-4234-8009-eca32c23d227
# 16  60d2fcab-0238-4ea9-9c1d-8351169d99a2
# 17  3a0669cc-bcd0-4de6-ba84-0cdecbf2606a
# 18  421e32e3-58d4-4b15-9c6c-ab8441718925
# 19  52e912c7-0193-4796-bd79-e6d5ff41b6f9
# 20  9b9e31bf-ef84-4fd1-a972-6483b02d0e35
# 21  f0a276a8-832c-4516-9471-9303fcd8f3e2
# 22  bd08b373-5690-49f0-bd85-1a7d3bc67486
# 23  522c256d-32f5-4a3e-b39b-c371c1aed923
#
#                                              document  \
# 0   Начисление и выплата бонусов сотрудникам являе...
# 1   После утверждения итогов бонусного периода, HR...
# 2   Процесс найма новых сотрудников в компанию пре...
# 3   Дополнительно может быть организовано тестиров...
# 4   Процесс согласования договоров является неотъе...
# 5   После получения замечаний и внесения правок пр...
# 6   Структура компании представляет собой иерархич...
# 7   Каждое подразделение имеет утвержденное положе...
# 8   Адаптация новых сотрудников является ключевым ...
# 9   Адаптационная программа может быть различной в...
# 10  Согласование платежей в компании регулируется ...
# 11  Система автоматически уведомляет всех согласую...
# 12  Начисление и выплата бонусов сотрудникам являе...
# 13  После утверждения итогов бонусного периода, HR...
# 14  Процесс найма новых сотрудников в компанию пре...
# 15  Дополнительно может быть организовано тестиров...
# 16  Процесс согласования договоров является неотъе...
# 17  После получения замечаний и внесения правок пр...
# 18  Структура компании представляет собой иерархич...
# 19  Каждое подразделение имеет утвержденное положе...
# 20  Адаптация новых сотрудников является ключевым ...
# 21  Адаптационная программа может быть различной в...
# 22  Согласование платежей в компании регулируется ...
# 23  Система автоматически уведомляет всех согласую...
#
#                         metadata embedding
# 0      {'source': 'bonuses.txt'}      None
# 1      {'source': 'bonuses.txt'}      None
# 2       {'source': 'hiring.txt'}      None
# 3       {'source': 'hiring.txt'}      None
# 4    {'source': 'contracts.txt'}      None
# 5    {'source': 'contracts.txt'}      None
# 6    {'source': 'structure.txt'}      None
# 7    {'source': 'structure.txt'}      None
# 8   {'source': 'onboarding.txt'}      None
# 9   {'source': 'onboarding.txt'}      None
# 10    {'source': 'payments.txt'}      None
# 11    {'source': 'payments.txt'}      None
# 12     {'source': 'bonuses.txt'}      None
# 13     {'source': 'bonuses.txt'}      None
# 14      {'source': 'hiring.txt'}      None
# 15      {'source': 'hiring.txt'}      None
# 16   {'source': 'contracts.txt'}      None
# 17   {'source': 'contracts.txt'}      None
# 18   {'source': 'structure.txt'}      None
# 19   {'source': 'structure.txt'}      None
# 20  {'source': 'onboarding.txt'}      None
# 21  {'source': 'onboarding.txt'}      None
# 22    {'source': 'payments.txt'}      None
# 23    {'source': 'payments.txt'}      None

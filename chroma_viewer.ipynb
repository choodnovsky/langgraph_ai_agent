# %%
import pandas as pd
import chromadb
from src.settings import settings

# %%
client = chromadb.HttpClient(
    host=settings.CHROMA_HOST,
    port=settings.CHROMA_PORT,
)

# %%
client.heartbeat()
# Out:
# 1771141909099450552

# %%
collection = client.get_collection(name=settings.COLLECTION_NAME)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 collection = client.get_collection(name=settings.COLLECTION_NAME)
#
# File ~/Documents/langgraph_pet/.venv/lib/python3.11/site-packages/chromadb/api/client.py:208, in Client.get_collection(self, name, embedding_function, data_loader)
#     199 @override
#     200 def get_collection(
#     201     self,
#    (...)    206     data_loader: Optional[DataLoader[Loadable]] = None,
#     207 ) -> Collection:
# --> 208     model = self._server.get_collection(
#     209         name=name,
#     210         tenant=self.tenant,
#     211         database=self.database,
#     212     )
#     213     persisted_ef_config = model.configuration_json.get("embedding_function")
#     215     validate_embedding_function_conflict_on_get(
#     216         embedding_function, persisted_ef_config
#     217     )
#
# File ~/Documents/langgraph_pet/.venv/lib/python3.11/site-packages/chromadb/telemetry/opentelemetry/__init__.py:150, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     148 global tracer, granularity
#     149 if trace_granularity < granularity:
# --> 150     return f(*args, **kwargs)
#     151 if not tracer:
#     152     return f(*args, **kwargs)
#
# File ~/Documents/langgraph_pet/.venv/lib/python3.11/site-packages/chromadb/api/fastapi.py:309, in FastAPI.get_collection(self, name, tenant, database)
#     300 @trace_method("FastAPI.get_collection", OpenTelemetryGranularity.OPERATION)
#     301 @override
#     302 def get_collection(
#    (...)    306     database: str = DEFAULT_DATABASE,
#     307 ) -> CollectionModel:
#     308     """Returns a collection"""
# --> 309     resp_json = self._make_request(
#     310         "get",
#     311         f"/tenants/{tenant}/databases/{database}/collections/{name}",
#     312     )
#     314     model = CollectionModel.from_json(resp_json)
#     315     return model
#
# File ~/Documents/langgraph_pet/.venv/lib/python3.11/site-packages/chromadb/api/fastapi.py:131, in FastAPI._make_request(self, method, path, **kwargs)
#     128 url = self._api_url + escaped_path
#     130 response = self._session.request(method, url, **cast(Any, kwargs))
# --> 131 BaseHTTPClient._raise_chroma_error(response)
#     132 return orjson.loads(response.text)
#
# File ~/Documents/langgraph_pet/.venv/lib/python3.11/site-packages/chromadb/api/base_http_client.py:129, in BaseHTTPClient._raise_chroma_error(resp)
#     126     pass
#     128 if chroma_error:
# --> 129     raise chroma_error
#     131 try:
#     132     resp.raise_for_status()
#
# NotFoundError: Collection [wiki_docs] does not exist

# %%
collection.count()
# Out:
# 4

# %%
data = collection.get(
    limit=100,
    offset=0,
    # include=["embeddings"]
)

# %%
df = pd.DataFrame({
    "id": data["ids"],
    "document": data["documents"],
    "metadata": data["metadatas"],
    "embedding": data["embeddings"],  # список float внутри каждой строки

})

# %%
df
# Out:
#                                      id  \
# 0  doc_e872549b899aa7cdbd91db17c38683b3
# 1  doc_bf2f4bebe78c95e5abe8bcb821eacd54
# 2  doc_8ae66c94ebb3d7daeb5698c5bda03af2
# 3  doc_6a4a514dbbb815b128e05612ff29ab8e
#
#                                             document  \
# 0  РЕГЛАМЕНТ\nпо начислению и выплате бонусов сот...
# 1  # РЕГЛАМЕНТ\n## по подбору и найму персонала\n...
# 2  # РЕГЛАМЕНТ\n## разработки и внедрения аналити...
# 3  # РЕГЛАМЕНТ\n## процесса бюджетирования\n### О...
#
#                                             metadata embedding
# 0  {'file_hash': '3d5599db76c7f34960f0158a01e0f36...      None
# 1  {'filepath': '/Users/victorchudnovskiy/Documen...      None
# 2  {'size': 19808, 'file_hash': '758726be25768ef1...      None
# 3  {'size': 16265, 'file_hash': '6d471a8ea94f2776...      None
